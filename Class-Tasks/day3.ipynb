# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import numpy as np
import pandas as pd
import matplotlib as mat

# %%
from math import sqrt,pi
print(sqrt(25))
# Out:
# 5.0

# %%
try:
    number=int (input("Enter a number:-"))
    result=10/number
    print('result:',result)

except ZeroDivisionError:
    print("Cannot divided by zero!")
except ValueError:
    print("Pleas enter valid number:")
finally:
    print("Compelted")
# Out:
# Pleas enter valid number:
# Compelted

# %% [markdown]
# # Write a claculator that handel division by zero,non-numeric input and unknown operation.

# %%
def calculator():
    try:
        num1 = float(input("Enter first number: "))
        operator = input("Enter operation (+, -, *, /): ")
        num2 = float(input("Enter second number: "))
        if operator == "+":
            result = num1 + num2
        elif operator == "-":
            result = num1 - num2
        elif operator == "*":
            result = num1 * num2
        elif operator == "/":
            if num2 == 0:
                print("Error: Division by zero is not allowed.")
                return
            result = num1 / num2
        else:
            print("Error: Unknown operation.")
            return

        print("Result:", result)

    except ValueError:
        print("Error: Please enter valid numeric values.")

calculator()
# Out:
# Error: Please enter valid numeric values.

# %% [markdown]
# # OR

# %%
def add(a,b):
    return a+b
def sub(a,b):
    return a+-b
def mul(a,b):
    return a*b
def div(a,b):
    return a/b
try:
    a=int(input("Enter 1st number:-"))
    print(a)
    b=int(input("Enter 2nd number"))
    print(b)
    print(f"Add {add(a,b)}")
    print(f"sub {sub(a,b)}")
    print(f"mul {mul(a,b)}")
    print(f"div {div(a,b)}")
except ZeroDivisionError:
    print("Divide by 0 error")
except ValueError:
    print("Value Error")
# Out:
# Value Error

# %% [markdown]
# "r":-Read  only             open nornally
# "w":-Write-overwrites       Erases & rewrite
# "a":-Append- add to end     Add at end

# %%
with open ("name.txt",'r') as f:
    content=f.read()
    print(content)
# Out:
# name: raj, score:85
# name: rohan, score:95
# name: ramesh, score:75
# name: deepak, score:96
# name: deepak, score:96

# %%
with open ("name.txt",'r') as f:
    for line in f:
        print(line.strip())
# Out:
# name: raj, score:85
# name: rohan, score:95
# name: ramesh, score:75
# name: deepak, score:96
# name: deepak, score:96

# %%
with open ("name.txt",'r') as f:
    content=f.readlines()
    print(content)
    print(len(content))
# Out:
# ['name: raj, score:85\n', 'name: rohan, score:95\n', 'name: ramesh, score:75\n', 'name: deepak, score:96\n', 'name: deepak, score:96\n']
# 5

# %%
with open ("name.txt",'w') as f:
    f.write("name: raj, score:85\n")
    f.write("name: rohan, score:95\n")
    f.write("name: ramesh, score:75\n")
print('File Saved')
# Out:
# File Saved

# %%
with open ("name.txt",'a') as f:
    f.write("name: deepak, score:96\n")
print("New Student Added In To File")
with open ("name.txt",'r') as f:
    content=f.read()
    print(content)
# Out:
# New Student Added In To File
# name: raj, score:85
# name: rohan, score:95
# name: ramesh, score:75
# name: deepak, score:96

# %%
import json 
student_dict={'name':'raj Kumer','score':50,'enrolled':True}
json_string=json.dumps(student_dict, indent=4)
print(json_string)
print(type(json_string))
# Out:
# {
#     "name": "raj Kumer",
#     "score": 50,
#     "enrolled": true
# }
# <class 'str'>

# %%
import json 
student_dict={'name':'raj Kumer','score':50,'enrolled':True}
json_string=json.dumps(student_dict)
print(json_string)
print(type(json_string))
# Out:
# {"name": "raj Kumer", "score": 50, "enrolled": true}
# <class 'str'>

# %% [markdown]
# Create s student profile dictionary. conver to json, print it ,then load ot back and print each value

# %%
student_dict={'name':'raj Kumer','score':50,'enrolled':True}
json_string=json.dumps(student_dict, indent=4)
print(json_string)
# Out:
# {
#     "name": "raj Kumer",
#     "score": 50,
#     "enrolled": true
# }

# %%
student_dict='{"name":"raj Kumer","score": 50}'
json_string=json.loads(student_dict)
print(json_string['name'])
print(json_string['score'])
# Out:
# raj Kumer
# 50

# %% [markdown]
# oop basic

# %%
class student:
    def __init__(self,name,score):
        self.name=name
        self.score=score
        self.grade='A' if score >=85
else 'B'
s1=student('raj',85)
s2=student('rohan',75)
# Out:
#   Cell In[24], line 5
#     self.grade='A' if score >=85
#                ^
# SyntaxError: expected 'else' after 'if' expression

# %%
import math 
import random

# %% [markdown]
#  # 1. Modules Challenge
#  ### Task: Generate 10 random float scores (50–100) using math and random, then find the mean, max, and min.

# %%
score = [round(random.uniform(50, 100),2) for i in range(11)]
mean=sum(score)/len(score)
print("mean:-",round(mean,2))
print("max:-",max(score))
print("min:-",min(score))
# Out:
# mean:- 76.58
# max:- 97.68
# min:- 51.16

# %% [markdown]
# # 2. File Handling Challenge
# ### Task: Create a student.txt file with 5 names and scores, read it, calculate the average, and print the top scorer.

# %%
total = 0
count = 0
score = 0

with open("name.txt", "r") as file:
    for line in file:
        name, scores = line.strip().split(",")
        scores = int(scores)
        total += scores
        count += 1
        if scores > score:
            score = scores

average = total / count

print("Average Score:", average)
print("Top Scorer:", score)
# Out:
# Average Score: 87.75
# Top Scorer: 96

# %% [markdown]
# # 3. JSON Challenge
# ### Task: Create an AI model configuration dictionary, convert it to JSON, save it, then load and print it.

# %% [markdown]
# #### convert it to JSON

# %%
student={'name':'raj Kumer','score':50,'enrolled':True}
# save the json
with open("student.json", "w") as file:
    json.dump(student_dict, file, indent=4)
    print(json_string)

#lode from json
with open("student.json", "r") as file:
    data=json.load(file)
    print(json_string['name'])
    print(json_string['score'])

# print dic
for key, value in json_string.items():
    print(key, ":", value)
# Out:
# {'name': 'raj Kumer', 'score': 50}
# raj Kumer
# 50
# name : raj Kumer
# score : 50

# %% [markdown]
# ## 4. OOP Challenge
#
# #### Task: Create a BankAccount class with deposit(), withdraw(), and get_balance() methods. Handle overdraft exceptions.

# %%
class BankAccount:
    def __init__(self, User, balance=0):
        self.User = User
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited {amount}")
        print(f"Total Balance: {self.balance}")

    def withdraw(self, amount):
        try:
            if amount > self.balance:
                raise Exception("Overdraft")

            self.balance -= amount
            print("Withdrawn:", amount)

        except Exception as e:
            print("Error:", e)

    def get_balance(self):
        print(f"Balance: {self.balance}")


acc = BankAccount("Deepak", 1000000)

acc.deposit(700000)
acc.withdraw(10000)
acc.get_balance()
acc.withdraw(10000000)
# Out:
# Deposited 700000
# Total Balance: 1700000
# Withdrawn: 10000
# Balance: 1690000
# Error: Overdraft
